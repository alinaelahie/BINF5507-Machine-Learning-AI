# %%
# import libraries
import pandas as pd

# load the dataset
data = pd.read_csv('/home/user/BINF 5507/Data/messy_data.csv')
 
#Examine the dataset
# display the first few rows
data.head()

# check overall info
data.info()

# get basic stats for numerical columns
data.describe()

# check for missing values
data.isnull().sum()

# check for duplicate columns
data.columns[data.columns.duplicated()]


# plot histograms 
import matplotlib.pyplot as plt
import seaborn as sns

data.hist(figsize=(10, 8), bins=50)
plt.tight_layout()
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1158 entries, 0 to 1157
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     1158 non-null   int64
#  1   deck         273 non-null    object
#  2   embarked     1155 non-null   object
#  3   pclass       1051 non-null   float64
#  4   embark_town  1155 non-null   object
#  5   sex          1158 non-null   object
#  6   adult_male   1158 non-null   bool
#  7   who          1158 non-null   object
#  8   wspd         929 non-null    float64
#  9   lfwa         929 non-null    float64
#  10  class        1158 non-null   object
#  11  tprc         1158 non-null   float64
#  12  sibsp        1044 non-null   float64
#  13  age          829 non-null    float64
#  14  alone        1158 non-null   bool
#  15  fare         1036 non-null   float64
#  16  parch        1042 non-null   float64
# dtypes: bool(2), float64(8), int64(1), object(6)
# ...

# %%
# Step 4: Apply the DataPreprocessor class

from data_preprocessor import DataPreprocessor
import data_preprocessor
import numpy as np

print(data_cleaned.columns)
data_cleaned.loc[:, 'class'] = data_cleaned['class'].map({'First': 1, 'Second': 2, 'Third': 3})

# handle missing values
data_cleaned = preprocessor.impute_missing_values(data)
print("Missing values handled.")

# remove duplicates
data_cleaned = preprocessor.remove_duplicates(data_cleaned)
print("Duplicates removed.")

# drop non-numeric columns
data_cleaned = data_cleaned.select_dtypes(include=[np.number])
print(data_cleaned.columns)  # Verify the columns after dropping non-numeric ones

# remove redundant features based on correlation
data_cleaned = preprocessor.remove_redundant_features(data_cleaned, threshold=0.9)
print("Redundant features removed.")


# Step 5: Save the cleaned data
cleaned_file_path = "/home/user/BINF 5507/Data/cleaned_data.csv"
data_cleaned.to_csv(cleaned_file_path, index=False)
print(f"Cleaned data saved to {cleaned_file_path}")
# Out:
# Index(['survived', 'pclass', 'wspd', 'lfwa', 'class', 'tprc', 'sibsp', 'fare',
#        'parch'],
#       dtype='object')
# Missing values handled.
# Duplicates removed.
# Index(['survived', 'pclass', 'wspd', 'lfwa', 'tprc', 'sibsp', 'age', 'fare',
#        'parch'],
#       dtype='object')
# Redundant features removed.
# Cleaned data saved to /home/user/BINF 5507/Data/cleaned_data.csv

# %%
# ============ below is code to answer short answer questions ================
import pandas as pd

# load the messy dataset
messy_data = pd.read_csv('/home/user/BINF 5507/Data/messy_data.csv')

# load the cleaned dataset
cleaned_data = pd.read_csv('/home/user/BINF 5507/Data/cleaned_data.csv')

# %%
# summary stats for messy data
print("Messy Data - Basic Info:")
print(messy_data.info())

print("\nMessy Data - Summary Statistics (Numerical):")
print(messy_data.describe())

print("\nMessy Data - Missing Values:")
print(messy_data.isnull().sum())
# Out:
# Messy Data - Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1158 entries, 0 to 1157
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     1158 non-null   int64
#  1   deck         273 non-null    object
#  2   embarked     1155 non-null   object
#  3   pclass       1051 non-null   float64
#  4   embark_town  1155 non-null   object
#  5   sex          1158 non-null   object
#  6   adult_male   1158 non-null   bool
#  7   who          1158 non-null   object
#  8   wspd         929 non-null    float64
#  9   lfwa         929 non-null    float64
#  10  class        1158 non-null   object
#  11  tprc         1158 non-null   float64
#  12  sibsp        1044 non-null   float64
#  13  age          829 non-null    float64
#  14  alone        1158 non-null   bool
#  15  fare         1036 non-null   float64
#  16  parch        1042 non-null   float64
# ...

# %%
# summary stats for cleaned data
print("Cleaned Data - Basic Info:")
print(cleaned_data.info())

print("\nCleaned Data - Summary Statistics (Numerical):")
print(cleaned_data.describe())

print("\nCleaned Data - Missing Values:")
print(cleaned_data.isnull().sum())
# Out:
# Cleaned Data - Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 832 entries, 0 to 831
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  832 non-null    int64
#  1   pclass    832 non-null    float64
#  2   wspd      832 non-null    float64
#  3   lfwa      832 non-null    float64
#  4   tprc      832 non-null    float64
#  5   sibsp     832 non-null    float64
#  6   fare      832 non-null    float64
#  7   parch     832 non-null    float64
# dtypes: float64(7), int64(1)
# memory usage: 52.1 KB
# None
#
# Cleaned Data - Summary Statistics (Numerical):
#          survived      pclass        wspd        lfwa         tprc  \
# count  832.000000  832.000000  832.000000  832.000000   832.000000
# mean     0.396635    2.276049   66.017947   59.600092   102.586552
# std      0.489493    0.798317   69.918998   26.871986   152.913400
# ...
